# %%
#import packages that I will use 
import numpy as np
import pandas as pd
import json
import csv

# %%
# Import ranking of bank accoridng to satisfaction rate
df = pd.read_csv('PROJECT statistictransparency-and-ethical-lending-of-selected-uk-saving-account-providers-2021.csv')
df
# Out:
#                                                  Name  \
# 0                                        Triodos Bank
# 1                                          Nationwide
# 2                              Leeds Building Society
# 3                            Skipton Building Society
# 4                            Ecology Building Society
# 5                 Co-operative Bank (inlc. Britannia)
# 6           NatWest Group (incl. RBS and Ulster Bank)
# 7   Lloyds Banking Group (incl. Halifax and Bank o...
# 8                                                HSBC
# 9                                      Aldermore Bank
# 10                         Yorkshire Building Society
# 11                                           Barclays
# 12                                          Santander
# 13                      Principality Building Society
# 14                                     Gatehouse Bank
# 15                                      Al Rayan Bank
# ...

# %%
# Here I am importing another data set 

df2 = pd.read_csv('project leading-uk-banks-by-number-of-customers-2021.csv')
df2
# Out:
#                                                 Name  \
# 0                                           Barclays
# 1                                               HSBC
# 2  Lloyds Banking Group (incl. Halifax and Bank o...
# 3          NatWest Group (incl. RBS and Ulster Bank)
# 4                                         Nationwide
# 5                                       Virgin Money
# 6                                         Metro Bank
# 7                                    Bank of Ireland
# 8                                       First Direct
#
#    Number of customers in millions
# 0                             48.00
# 1                             40.00
# 2                             26.00
# 3                             19.00
# 4                             16.30
# 5                              6.50
# 6                              2.50
# 7                              2.00
# 8                              1.45

# %% [markdown]
# https://www.statista.com/statistics/1283369/ethical-lending-scores-of-banks-uk/
#
# https://www.statista.com/statistics/386749/uk-leading-banks-by-customer-satisfaction/

# %%
# Merging both cvs file on a comment value 

df3 =pd.merge(df, df2)
df3
# Out:
#                                                 Name  \
# 0                                         Nationwide
# 1          NatWest Group (incl. RBS and Ulster Bank)
# 2  Lloyds Banking Group (incl. Halifax and Bank o...
# 3                                               HSBC
# 4                                           Barclays
# 5                                         Metro Bank
#
#    Ethical Company Index Score  Number of customers in millions
# 0                           30                              16.3
# 1                           13                              19.0
# 2                           13                              26.0
# 3                           13                              40.0
# 4                            8                              48.0
# 5                            3                               2.5

# %%
# export as json
exported_values = list(df3.T.to_dict().values() )
open('UK banks satisfaction rate on number of cutomers.json','w').write( json.dumps(exported_values) )
# Out:
# 673
